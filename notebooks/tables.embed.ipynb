# %% [markdown]
# # Tables
#
# Stephanie Ward

# %%
library(tidyverse)
# Out:
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.5
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   4.0.0     ✔ tibble    3.3.0
# ✔ lubridate 1.9.4     ✔ tidyr     1.3.1
# ✔ purrr     1.0.4
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Attaching package: 'kableExtra'
#
# The following object is masked from 'package:dplyr':
#
#     group_rows

# %%
knitr::opts_chunk$set(dev = "png")

# %%
icc_table <- readRDS(here::here("objects/icc_table.rds"))

# %%
#| label: tbl-icc
#| tbl-cap: Intraclass correlation coefficients for sexual consent cue use.

icc_table <- icc_table %>%
  mutate(
    ICC = ICC |> str_replace("^0\\.", "."),
    `1 - ICC` = `1 - ICC` |> str_replace("^0\\.", "."),
    `95% CI` = `95% CI` |> str_replace("\\b0\\.", ".")
  )

icc_table %>%
  kbl(
    booktabs = TRUE,
    align = c("l", "c", "c", "c")
  ) %>%
  kable_styling(full_width = FALSE)
# Out:
# <table class="table" style="width: auto !important; margin-left: auto; margin-right: auto;">
#  <thead>
#   <tr>
#    <th style="text-align:left;"> Outcome </th>
#    <th style="text-align:center;"> ICC </th>
#    <th style="text-align:center;"> 95% CI </th>
#    <th style="text-align:center;"> 1 - ICC </th>
#   </tr>
#  </thead>
# <tbody>
#   <tr>
#    <td style="text-align:left;"> Verbal cues </td>
#    <td style="text-align:center;"> .524 </td>
#    <td style="text-align:center;"> [.387, .528] </td>
#    <td style="text-align:center;"> .476 </td>
#   </tr>
#   <tr>
#    <td style="text-align:left;"> Nonverbal cues </td>
#    <td style="text-align:center;"> .677 </td>
#    <td style="text-align:center;"> [.584, .687] </td>
#    <td style="text-align:center;"> .323 </td>
#   </tr>
# </tbody>
# </table>
